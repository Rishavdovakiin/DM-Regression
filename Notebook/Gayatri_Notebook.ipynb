# %%
# !pip uninstall -y scikit-learn
#!pip install scikit-learn --upgrade
# Out:
# Found existing installation: scikit-learn 1.5.2
# Uninstalling scikit-learn-1.5.2:
#   Successfully uninstalled scikit-learn-1.5.2

# %%
# !pip install --force-reinstall scikit-learn==1.5.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.8 MB/s eta 0:00:00
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 36.4 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 37.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 12.7 MB/s eta 0:00:00
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# ...
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
# ...

# %%
# !pip install numpy==1.24
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 77.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.15 requires numpy>=1.24.4, but you have numpy 1.24.0 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.24.0 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.
# seaborn 0.13.1 requires numpy!=1.24.0,>=1.20, but you have numpy 1.24.0 which is incompatible.
# ...

# %%
import pandas as pd
import numpy as np
import sklearn

df = np.genfromtxt("https://halos.as.arizona.edu/simulations/BolshoiP/hlists/hlist_0.06012.list", comments='#', max_rows=10000)

# %%
df[df == 0] = 1e-10

# Defining halo properties
virial_mass = np.log10(df[:,10])
virial_radius = np.log10(df[:, 11])
concentration = np.log10(df[:, 11]/df[:, 12])
velocity_dispersion = np.log10(df[:, 13])
max_circular_velocity = np.log10(df[:, 16])
spin = np.log10(df[:, 26])
b_to_a = df[:, 44]
c_to_a = df[:, 45]
energy_ratio = df[:, 54]
peak_mass = np.log10(df[:, 58])
peak_Vmax = np.log10(df[:, 60])
half_mass = df[:, 61]
peak_mass_a = np.log10(df[:, 67])
acc_rate = df[:, 64]

halo_props = pd.DataFrame({'Virial Mass': virial_mass,
              'Virial Radius': virial_radius,
              'Concentration': concentration,
              'Velocity Disp': velocity_dispersion,
              'Vmax':max_circular_velocity,
              'Spin': spin,
              'B to A': b_to_a,
              'C to A': c_to_a,
              'Energy ratio': energy_ratio,
              'Peak Mass': peak_mass,
              'peak Vmax': peak_Vmax,
              'Halfmass a': half_mass,
              'Peakmass a': peak_mass_a,
              'Acc Rate': acc_rate})
# Out:
# <ipython-input-5-6fc92ef8baf9>:16: RuntimeWarning: invalid value encountered in log10
#   peak_mass_a = np.log10(df[:, 67])

# %%
halo_props.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Virial Mass'}>,
#         <Axes: title={'center': 'Virial Radius'}>,
#         <Axes: title={'center': 'Concentration'}>,
#         <Axes: title={'center': 'Velocity Disp'}>],
#        [<Axes: title={'center': 'Vmax'}>,
#         <Axes: title={'center': 'Spin'}>,
#         <Axes: title={'center': 'B to A'}>,
#         <Axes: title={'center': 'C to A'}>],
#        [<Axes: title={'center': 'Energy ratio'}>,
#         <Axes: title={'center': 'Peak Mass'}>,
#         <Axes: title={'center': 'peak Vmax'}>,
#         <Axes: title={'center': 'Halfmass a'}>],
#        [<Axes: title={'center': 'Peakmass a'}>,
#         <Axes: title={'center': 'Acc Rate'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
halo_props
# Out:
#       Virial Mass  Virial Radius  Concentration  Velocity Disp      Vmax  \
# 0        8.491222       1.229631       0.917877     -10.000000  1.621695
# 1        8.792322       1.329967       0.546135       1.393048  1.667546
# 2        8.889190       1.362275       0.479694       1.492621  1.695044
# 3        9.231724       1.476426       1.093869       1.787815  1.907841
# 4        9.269513       1.489016       0.522546       1.740363  1.824711
# ...           ...            ...            ...            ...       ...
# 1004     8.792322       1.329967       0.751213       1.496930  1.692230
# 1005     8.889190       1.362275       0.957270       1.455758  1.762453
# 1006     8.889190       1.362275       0.599597       1.579898  1.704837
# 1007     9.093422       1.430317       0.853515       1.632356  1.809896
# 1008     8.491222       1.229631       0.818685     -10.000000  1.602928
#
#            Spin        B to A        C to A  Energy ratio  Peak Mass  \
# ...

# %%
# Saving the file into csv file
halo_props.to_csv('halo_Props.csv', index=False)

# %%
halo = pd.read_csv('halo_Props.csv')
halo
# Out:
#       Virial Mass  Virial Radius  Concentration  Velocity Disp      Vmax  \
# 0        8.491222       1.229631       0.917877     -10.000000  1.621695
# 1        8.792322       1.329967       0.546135       1.393048  1.667546
# 2        8.889190       1.362275       0.479694       1.492621  1.695044
# 3        9.231724       1.476426       1.093869       1.787815  1.907841
# 4        9.269513       1.489016       0.522546       1.740363  1.824711
# ...           ...            ...            ...            ...       ...
# 1004     8.792322       1.329967       0.751213       1.496930  1.692230
# 1005     8.889190       1.362275       0.957270       1.455758  1.762453
# 1006     8.889190       1.362275       0.599597       1.579898  1.704837
# 1007     9.093422       1.430317       0.853515       1.632356  1.809896
# 1008     8.491222       1.229631       0.818685     -10.000000  1.602928
#
#            Spin        B to A        C to A  Energy ratio  Peak Mass  \
# ...

# %%
#Applying data preprocessing:1.Checking missing values:
halo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Virial Mass    1009 non-null   float64
#  1   Virial Radius  1009 non-null   float64
#  2   Concentration  1009 non-null   float64
#  3   Velocity Disp  1009 non-null   float64
#  4   Vmax           1009 non-null   float64
#  5   Spin           1009 non-null   float64
#  6   B to A         1009 non-null   float64
#  7   C to A         1009 non-null   float64
#  8   Energy ratio   1009 non-null   float64
#  9   Peak Mass      1009 non-null   float64
#  10  peak Vmax      1009 non-null   float64
#  11  Halfmass a     1009 non-null   float64
#  12  Peakmass a     1006 non-null   float64
#  13  Acc Rate       1009 non-null   float64
# dtypes: float64(14)
# memory usage: 110.5 KB

# %%
#Converting dataframe to numpy:
arr = halo.to_numpy()

# %%
#Splitting the dataset into training dataset and test data set:
from sklearn.model_selection import train_test_split

#Performing the split:
train, test = train_test_split(halo,test_size=0.2,random_state=23)
print(train,test)
# Out:
#      Virial Mass  Virial Radius  Concentration  Velocity Disp      Vmax  \
# 536     9.231724       1.476426       0.665924       1.720655  1.826658
# 407     8.667360       1.288339       0.848690       1.248954  1.666986
# 907     8.792322       1.329967       0.648997       1.478278  1.678154
# 45      9.512418       1.570029       0.883303       1.864036  1.955255
# 986     9.394452       1.530661       0.772354       1.843482  1.896251
# ..           ...            ...            ...            ...       ...
# 950     8.792322       1.329967       0.801436       1.354876  1.700358
# 969     9.035430       1.410996       0.766853       1.639984  1.775683
# 40      9.445449       1.547713       0.614023       1.830268  1.891816
# 742     8.792322       1.329967       1.204161       1.487138  1.789440
# 595     8.968390       1.388669       0.673000       1.560624  1.739810
#
#          Spin        B to A   C to A  Energy ratio  Peak Mass  peak Vmax  \
# ...

# %%
#Stratified split according to virial mass
#To be unbiased by the distribution of feature values, we can use stratified sampling.
#For this the split is not performed randomly, but sampled from subgroups (=strata) of a feature.
#Here we use the virial mass as a strata, and first define for each object, in which mass band it falls
from sklearn.model_selection import StratifiedShuffleSplit
cat_per_dex = 2.0 #This is the number of mass bands per dex of halo mass
mass_band = np.floor((virial_mass - virial_mass.min())*cat_per_dex)

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=23)
for train_index, test_index in split.split(halo, mass_band):
    strat_train_set = halo.loc[train_index]
    strat_test_set = halo.loc[test_index]

# %%
#Copy stratified training set to halos data frame
#Copy the training set to the halos data frame using the .copy() function
halos = strat_train_set.copy()

# %%
#Compute correlation matrix and show highest correlations for a given property
#The .corr() function gives you the correlation matrix
#You can then print the result with the ['Name of Feature'] subscript
#If you add .sort_values() the results will get sorted
corr_matrix = halos.corr()
print(corr_matrix['Concentration'].sort_values())
# Out:
# Peak Mass       -0.343639
# B to A          -0.333329
# C to A          -0.318044
# Spin            -0.292681
# Velocity Disp   -0.206986
# Peakmass a      -0.031087
# peak Vmax       -0.015608
# Virial Mass     -0.014622
# Virial Radius   -0.014578
# Energy ratio     0.036539
# Acc Rate         0.093753
# Vmax             0.362742
# Halfmass a       0.399044
# Concentration    1.000000
# Name: Concentration, dtype: float64

# %%
#Import the libraries necessary for the rest of the code
from sklearn.model_selection import cross_val_score #used to prevent overfitting
from sklearn.model_selection import GridSearchCV #Helps to find the optimal parameter values out of a given set of parameter values in a given datset
from sklearn.impute import SimpleImputer #Helps fill out on missing values
from sklearn.preprocessing import MinMaxScaler #Converts the data to fit in a certain range eg. (0,1)
from sklearn.preprocessing import StandardScaler#Only shifts and scales values within a certain range
from sklearn.pipeline import Pipeline #Stores the series of work that has to be done one after the other

# %%
#Select most highly correlated features and show scatter plots
attributes=['Concentration','Halfmass a', 'Peakmass a', 'C to A', 'B to A']
pd.plotting.scatter_matrix(halos[attributes], figsize=(12,8))
# Out:
# array([[<Axes: xlabel='Concentration', ylabel='Concentration'>,
#         <Axes: xlabel='Halfmass a', ylabel='Concentration'>,
#         <Axes: xlabel='Peakmass a', ylabel='Concentration'>,
#         <Axes: xlabel='C to A', ylabel='Concentration'>,
#         <Axes: xlabel='B to A', ylabel='Concentration'>],
#        [<Axes: xlabel='Concentration', ylabel='Halfmass a'>,
#         <Axes: xlabel='Halfmass a', ylabel='Halfmass a'>,
#         <Axes: xlabel='Peakmass a', ylabel='Halfmass a'>,
#         <Axes: xlabel='C to A', ylabel='Halfmass a'>,
#         <Axes: xlabel='B to A', ylabel='Halfmass a'>],
#        [<Axes: xlabel='Concentration', ylabel='Peakmass a'>,
#         <Axes: xlabel='Halfmass a', ylabel='Peakmass a'>,
#         <Axes: xlabel='Peakmass a', ylabel='Peakmass a'>,
#         <Axes: xlabel='C to A', ylabel='Peakmass a'>,
#         <Axes: xlabel='B to A', ylabel='Peakmass a'>],
#        [<Axes: xlabel='Concentration', ylabel='C to A'>,
# ...

# %%
#Select label for training and drop label from data set
halos_labels = strat_train_set['Concentration'].copy()
halos = strat_train_set.drop('Concentration', axis=1)

# %%
#Load an 'imputer' that fills missing data with median values of the remaining data set
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
imputer.fit(halos)
halos_tr = pd.DataFrame(imputer.transform(halos),columns=halos.columns)

# %%
#We cannot directly feed a Pandas data frame to scikit-learn.
#Therefore we need to difine a class that transforms our data fram into a numpy array.
#Define class to select a pandas data frame for sklearn input
from sklearn.base import BaseEstimator, TransformerMixin
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self,X):
        return X[self.attribute_names].values

# %%
# Define attributes for min-max scaling
minmax_attribs = ['Peakmass a', 'C to A', 'B to A', ]

# Define attributes for standard scaling
scaler_attribs = ['Virial Radius', 'Virial Mass', 'peak Vmax', 'Peak Mass', 'Vmax', 'Spin']

# Check for attributes in minmax_attribs that are not in halos
missing_minmax = [attrib for attrib in minmax_attribs if attrib not in halos]
if missing_minmax:
    print(f"Missing attributes in minmax_attribs: {missing_minmax}")

# Check for attributes in scaler_attribs that are not in halos
missing_scaler = [attrib for attrib in scaler_attribs if attrib not in halos]
if missing_scaler:
    print(f"Missing attributes in scaler_attribs: {missing_scaler}")

# If there are no missing attributes, proceed with removing them from other_attribs
if not missing_minmax and not missing_scaler:
    other_attribs  = list(halos)
    for i in minmax_attribs:
        other_attribs.remove(i)
    for i in scaler_attribs:
        other_attribs.remove(i)
else:
    print("Please correct the missing attributes in minmax_attribs or scaler_attribs.")

# %%
#Set pipeline
#Here we define the pipelines for each attribute category (min-max, standard, other).
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline
#Pipeline for min-maxing
minmax_pipeline = Pipeline([
    ('selector', DataFrameSelector(minmax_attribs)),
    ('imputer',  SimpleImputer(strategy='median')),
    ('minmax',   MinMaxScaler())
    ])

#Pipeline for standard scaling
scaler_pipeline = Pipeline([
    ('selector', DataFrameSelector(scaler_attribs)),
    ('imputer',  SimpleImputer(strategy='mean')),
    ('standard', StandardScaler())
    ])

#Pipeline for no scaling
#Note that no scaler has to be selected
other_pipeline = Pipeline([
    ('selector', DataFrameSelector(other_attribs)),
    ('imputer',  SimpleImputer(strategy='median'))
    ])

#Combine Pipelines
#Add all three pipelines together
full_pipeline  = FeatureUnion(transformer_list=[
        ('minmax_pipeline', minmax_pipeline),
        ('scaler_pipeline', scaler_pipeline),
        ('other_pipeline', other_pipeline)
    ])

# %%
#Run halos through input pipeline to create scaled numpy array
halos_prepared = full_pipeline.fit_transform(halos)

# %% [markdown]
# 1.***Random Forests***

# %%
#Random Forests
#Define the Regressor. Use RandomForestRegressor() here.
#Fit the regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
forest_reg = RandomForestRegressor()
forest_reg.fit(halos_prepared,halos_labels)

#forest_mse = mean_squared_error(halos_labels, con_predictions_forest)
#forest_rmse = np.sqrt(forest_mse)
#forest_rmse
# Out:
# RandomForestRegressor()

# %%
#Compute Predictions and determine RMSE
con_predictions_forest = forest_reg.predict(halos_prepared)

# %%
#Define function for validation output
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard Deviation:", scores.std())

# %%
#Cross validate
scores =  cross_val_score(forest_reg,halos_prepared,halos_labels,cv=10,scoring="neg_mean_squared_error")
forest_rmse_scores = scores
display_scores(forest_rmse_scores)
# Out:
# Scores: [-0.00385797 -0.00291809 -0.00276256 -0.00403785 -0.00144555 -0.00311219
#  -0.00303479 -0.00438682 -0.00566662 -0.0049268 ]
# Mean: -0.003614923411862498
# Standard Deviation: 0.001152033198047518

# %%
#Plot prediction vs label
from matplotlib import pyplot as plt
plt.plot(con_predictions_forest, halos_labels, '.');
plt.plot(halos_labels, halos_labels);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %% [markdown]
# 2.***Bagging Regression***

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

bag_reg = BaggingRegressor()
bag_reg.fit(halos_prepared,halos_labels)
# Out:
# BaggingRegressor()

# %%
#Compute Predictions and determine RMSE
con_predictions_bag = bag_reg.predict(halos_prepared)

# %%
#Cross validate
scores =  cross_val_score(bag_reg,halos_prepared,halos_labels,cv=10,scoring="neg_mean_squared_error")
bag_rmse_scores = scores
display_scores(bag_rmse_scores)
# Out:
# Scores: [-0.00470564 -0.00231621 -0.00316053 -0.00398018 -0.0020777  -0.003448
#  -0.00421655 -0.00494587 -0.00594714 -0.00565849]
# Mean: -0.004045631043200237
# Standard Deviation: 0.0012450212939388056

# %%
#Plot prediction vs label
plt.plot(con_predictions_bag, halos_labels, '.');
plt.plot(halos_labels, halos_labels);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %% [markdown]
# ***3.Etra Tree Regression***

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
etra_reg = ExtraTreesRegressor()
etra_reg.fit(halos_prepared,halos_labels)
# Out:
# ExtraTreesRegressor()

# %%
#Compute Predictions and determine RMSE
con_predictions_etra = etra_reg.predict(halos_prepared)

# %%
#Cross validate
scores =  cross_val_score(etra_reg,halos_prepared,halos_labels,cv=10,scoring="neg_mean_squared_error")
etra_rmse_scores = scores
display_scores(etra_rmse_scores)
# Out:
# Scores: [-0.00114278 -0.00151024 -0.00112967 -0.00193186 -0.00104963 -0.00186969
#  -0.00234569 -0.00206694 -0.00283833 -0.00233807]
# Mean: -0.0018222902471801898
# Standard Deviation: 0.0005729096096559286

# %%
#Plot prediction vs label
plt.plot(con_predictions_etra, halos_labels, '.');
plt.plot(halos_labels, halos_labels);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %% [markdown]
# **Conclusion:**There is a chance that this model could overfit,hence we can say that a more complex method cannot be used when it overfits like this.

# %%
#Define function for validation output
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard Deviation:", scores.std())

# %%
#Cross validate with cross_val_score() - insert the etra regressor, input and labels
#We us 10 folds, so cv=10
#The method expects a utility function (greater is better), so we need to use negative mean squared errors!
#For this use scoring="neg_mean_squared_error" inside cross_val_score
scores = cross_val_score(etra_reg,halos_prepared,halos_labels,cv=10,scoring="neg_mean_squared_error")
#Compute RMSE and display
etra_rmse_scores =  scores
display_scores(etra_rmse_scores)
# Out:
# Scores: [-0.00134376 -0.00161803 -0.00104723 -0.00204382 -0.00106039 -0.00174429
#  -0.00226948 -0.00213343 -0.0029265  -0.0021442 ]
# Mean: -0.0018331127112367466
# Standard Deviation: 0.000559071581769385

# %%
#Cross validate forest regressor
forest_rmse_scores = cross_val_score(forest_reg,halos_prepared,halos_labels,cv=10,scoring="neg_mean_squared_error")
display_scores(forest_rmse_scores)
# Out:
# Scores: [-0.00383891 -0.0027187  -0.00271965 -0.00393095 -0.00158615 -0.00289037
#  -0.00292915 -0.0041376  -0.00568018 -0.00447592]
# Mean: -0.0034907579154342004
# Standard Deviation: 0.001095061081783213

# %% [markdown]
# *Hyperparameter grid search for* 1.**Random Forests**

# %%
#Perform hyperparameter grid search
#Here we first search 3x4=12 combinations of n_estimators and max_features.
#Then we set bootstrap to False and search 2x3=6 combinations.
#This training will take some time... Grab a coffee in the meanwhile...
param_grid = [
    {'n_estimators': [3,10,30], 'max_features': [2, 4, 6, 8]},
    {'bootstrap': [False], 'n_estimators': [3,10], 'max_features': [2, 3, 4]},
]

#Use Random Forests
forest_reg = RandomForestRegressor()

#Define grid search and fit
grid_search1 = GridSearchCV(forest_reg, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search1.fit(halos_prepared, halos_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   copy = True
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              scoring='neg_mean_squared_error')

# %%
#Show best hyperparameters
#They are stored in grid_search (use its best_params_ array)
grid_search1.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
#Show best estimator
#They are stored in grid_search (use its best_estimator_ array)
grid_search1.best_estimator_
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30)

# %%
#Compute Predictions and determine RMSE for best estimator
forest_reg = RandomForestRegressor(max_features=8,n_estimators=30)
forest_reg.fit(halos_prepared,halos_labels)
con_predictions = forest_reg.predict(halos_prepared)

# %%
#Cross validate
scores =  cross_val_score(forest_reg,halos_prepared,halos_labels,cv=10,scoring="neg_mean_squared_error")
grid_rmse_scores = scores
display_scores(grid_rmse_scores)
# Out:
# Scores: [-0.00340515 -0.00260212 -0.00266044 -0.00502221 -0.00156205 -0.00366864
#  -0.00312173 -0.00341    -0.00549639 -0.00435922]
# Mean: -0.003530793351996212
# Standard Deviation: 0.001117442021426538

# %%
#Plot prediction vs label
plt.plot(con_predictions, halos_labels, '.');
plt.plot(halos_labels, halos_labels);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %% [markdown]
# ***Hyperparameter grid search 2. Bagging Regression***

# %%
param_grid = [
    {'n_estimators': [3,10,30], 'max_features': [2, 4, 6, 8]},
    {'bootstrap': [False], 'n_estimators': [3,10], 'max_features': [2, 3, 4]},
]

#Use Random Forests
bag_reg = BaggingRegressor()

#Define grid search and fit
grid_search2 = GridSearchCV(bag_reg, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search2.fit(halos_prepared, halos_labels)
# Out:
# GridSearchCV(cv=5, estimator=BaggingRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              scoring='neg_mean_squared_error')

# %%
#Show best hyperparameters
#They are stored in grid_search (use its best_params_ array)
grid_search2.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
#Show best estimator
#They are stored in grid_search (use its best_estimator_ array)
grid_search2.best_estimator_
# Out:
# BaggingRegressor(max_features=8, n_estimators=30)

# %%
#Compute Predictions and determine RMSE for best estimator
bag_reg = BaggingRegressor(max_features=8,n_estimators=30)
bag_reg.fit(halos_prepared,halos_labels)
con_predictions = bag_reg.predict(halos_prepared)

# %%
#Cross validate
scores =  cross_val_score(bag_reg,halos_prepared,halos_labels,cv=10,scoring="neg_mean_squared_error")
grid_rmse_scores = scores
display_scores(grid_rmse_scores)
# Out:
# Scores: [-0.00339673 -0.00219999 -0.002461   -0.00403899 -0.00137543 -0.00275073
#  -0.00357057 -0.0049482  -0.00696018 -0.00420976]
# Mean: -0.003591157037979309
# Standard Deviation: 0.0015047166831603156

# %%
#Plot prediction vs label
plt.plot(con_predictions, halos_labels, '.');
plt.plot(halos_labels, halos_labels);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %% [markdown]
# ***Hyperparameters for 3.Etra Tree Regression***

# %%
param_grid = [
    {'n_estimators': [3,10,30], 'max_features': [2, 4, 6, 8]},
    {'bootstrap': [False], 'n_estimators': [3,10], 'max_features': [2, 3, 4]},
]

#Use Random Forests
etra_reg = ExtraTreesRegressor()

#Define grid search and fit
grid_search3 = GridSearchCV(etra_reg, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search3.fit(halos_prepared, halos_labels)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              scoring='neg_mean_squared_error')

# %%
#Show best hyperparameters
#They are stored in grid_search (use its best_params_ array)
grid_search3.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
#Show best estimator
#They are stored in grid_search (use its best_estimator_ array)
grid_search3.best_estimator_
# Out:
# ExtraTreesRegressor(max_features=8, n_estimators=30)

# %%
#Compute Predictions and determine RMSE for best estimator
etra_reg = ExtraTreesRegressor(max_features=8,n_estimators=30)
etra_reg.fit(halos_prepared,halos_labels)
con_predictions = etra_reg.predict(halos_prepared)

# %%
#Cross validate
scores =  cross_val_score(etra_reg,halos_prepared,halos_labels,cv=10,scoring="neg_mean_squared_error")
grid_rmse_scores = scores
display_scores(grid_rmse_scores)
# Out:
# Scores: [-0.00128456 -0.00166633 -0.0012251  -0.00209475 -0.00137168 -0.00150165
#  -0.00270916 -0.00200829 -0.00363682 -0.00237104]
# Mean: -0.0019869373494294197
# Standard Deviation: 0.00072068647921073

# %%
#Plot prediction vs label
plt.plot(con_predictions, halos_labels, '.');
plt.plot(halos_labels, halos_labels);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %% [markdown]
# ***Final testing of the models:***

# %%
#Evaluate the system in the test set
final_model = grid_search1.best_estimator_

X_test = strat_test_set.drop('Concentration', axis=1)
y_test = strat_test_set['Concentration'].copy()

X_test_prepared = full_pipeline.transform(X_test)

final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 0.0692207636924745

# %%
#Plot prediction vs label
plt.plot(final_predictions, y_test, '.');
plt.plot(y_test, y_test);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %% [markdown]
# ***Test on Model 2:***

# %%
#Evaluate the system in the test set
final_model = grid_search2.best_estimator_

X_test = strat_test_set.drop('Concentration', axis=1)
y_test = strat_test_set['Concentration'].copy()

X_test_prepared = full_pipeline.transform(X_test)

final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 0.06253151288987524

# %%
#Plot prediction vs label
plt.plot(final_predictions, y_test, '.');
plt.plot(y_test, y_test);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %% [markdown]
# ***Test on Model 3:***

# %%
#Evaluate the system in the test set
final_model = grid_search3.best_estimator_

X_test = strat_test_set.drop('Concentration', axis=1)
y_test = strat_test_set['Concentration'].copy()

X_test_prepared = full_pipeline.transform(X_test)

final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 0.04703722860334519

# %%
#Plot prediction vs label
plt.plot(final_predictions, y_test, '.');
plt.plot(y_test, y_test);
plt.xlabel('Predictions');
plt.ylabel('Labels');

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# For this particular Etra Regression,as it is overfitting,we can compare the values of RMSE:
#
# Train RMSE Value:      -0.001821260823300009
#
# ---
#
#
# Tuning RMSE Value:     -0.0019059672303729433
#
#
# ---
#
#
# Test RMSE Value:    0.04621595217783302

# %% [markdown]
# As for Random Forests
# RMSE: 0.06837937036890854
#
#
# For Bagging Regression
# RMSE :0.06886248879937683

# %% [markdown]
# ***THE END***

# %%
import joblib

# Save the preprocessing pipeline to Google Drive
joblib.dump(full_pipeline, '/content/drive/MyDrive/full_pipeline_gayatri2.pkl')
print("Preprocessing pipeline saved as 'full_pipeline_gayatri2.pkl' in Google Drive")

# Save the best Forrest Regression model (after hyperparameter tuning)

joblib.dump(forest_reg, '/content/drive/MyDrive/best_forest_model2.pkl')
print("Best Forest model saved as 'best_forest_model2.pkl' in Google Drive")

# %%
import joblib

# Save the preprocessing pipeline to Google Drive
joblib.dump(full_pipeline, '/content/drive/MyDrive/full_pipeline.pkl')
print("Preprocessing pipeline saved as 'full_pipeline.pkl' in Google Drive")

# Save the best Forrest Regression model (after hyperparameter tuning)

joblib.dump(forest_reg, '/content/drive/MyDrive/best_xgb_model.pkl')
print("Best XGBoost model saved as 'best_xgb_model.pkl' in Google Drive")
